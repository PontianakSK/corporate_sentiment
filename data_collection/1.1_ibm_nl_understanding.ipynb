# %%
import csv
from time import time

import pandas as pd
from pandas import DataFrame

from Utils.ibm_nl import check_texts

# %%
def drop_and_write_header():
    
    with open('orgs_ibm_checked.csv','w',encoding='utf8') as orgs_file:
        field_names = [
            'uuid',
            'organization',
            'sentiment_score',
            'sentiment_label',
            'org_relevance',
            'org_count',
            'confidence',
            'orgs_in_doc',
        ]
        writer = csv.DictWriter(orgs_file,fieldnames=field_names)
        writer.writeheader()
    counter = {
        # Number of organizations with confidence greater than 0.6 and number of organizations 
        # in same doc less than or equal to 5.
        'le_5_orgs_conf_gt_06': {
            'negative': 0, 
            'positive': 0,
            'neutral': 0,
        }, 
        'others': {
            'negative': 0, 
            'positive': 0,
            'neutral': 0,
        }
    }
    
    with open('docs_counter.tmp','w') as counter_file:
        json.dump(counter,counter_file)

# %%
def write_orgs(orgs:List[Dict]):
    
    with open('docs_counter.tmp','r') as counter_file:
        counter = json.load(counter_file)
        
    with open('orgs_ibm_checked.csv','a',encoding='utf8') as orgs_file:
        field_names = [
            'uuid',
            'organization',
            'sentiment_score',
            'sentiment_label',
            'org_relevance',
            'org_count',
            'confidence',
            'orgs_in_doc',
        ]
        writer = csv.DictWriter(orgs_file,fieldnames=field_names)
        for org in orgs:
            sentiment = org.get('sentiment_label')
            confidence = org.get('confidence')
            orgs_in_doc = org.get('orgs_in_doc')
            if sentiment and confidence and orgs_in_doc:
                if (org['confidence'] >= 0.6) and (org['orgs_in_doc'] <= 5):
                    counter['le_5_orgs_conf_gt_06'][sentiment] += 1
                else:
                    counter['others'][sentiment] += 1
            writer.writerow(org)
        print(counter,'\n')
    
    with open('docs_counter.tmp','w') as counter_file:
        json.dump(counter,counter_file)

# %%
docs = pd.read_csv('csvs/docs_for_normalized_orgs.csv')

# %%
def get_rest_texts(docs: DataFrame, processed_uids: List[str]=[]):
    
    rest_texts = []
    rest_docs = docs[~docs.uuid.isin(processed_uids)]
    
    def add_text(row, list_):
        list_.append((row['uuid'],row['text']))
        
    rest_docs.apply(add_text, axis=1, args=[rest_texts])
    
    return rest_texts

# %%
def get_done_texts():
    
    done_texts = set(pd.read_csv('orgs_ibm_checked.csv')['uuid'])
    
    return list(done_texts)

# %%
docs = pd.read_csv('csvs/docs_for_normalized_orgs.csv')

# %%
rest_docs = get_rest_texts(docs, get_done_texts())
total = len(rest_docs)
step = min(1000, total)
start = time()

for i in range(0,total,step):
    batch_start = time()
    batch = rest_docs[i:i+step]
    result = await check_texts(batch, 20)
    write_orgs(result)
    print(f'{i+step} of {total} processed\n',f'Batch time: {time()-batch_start} s\n',f'Total time: {time()-start} s\n')
# Out:
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 2956, 'positive': 2305, 'neutral': 1911}, 'others': {'negative': 5349, 'positive': 10391, 'neutral': 12555}}
#
# 1000 of 46233 processed
#  Batch time: 87.81618332862854 s
#  Total time: 87.81630444526672 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 3531, 'positive': 2689, 'neutral': 2207}, 'others': {'negative': 6353, 'positive': 12151, 'neutral': 14231}}
#
# 2000 of 46233 processed
#  Batch time: 84.93735384941101 s
#  Total time: 172.75372791290283 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 4133, 'positive': 3028, 'neutral': 2521}, 'others': {'negative': 7247, 'positive': 14006, 'neutral': 16195}}
#
# 3000 of 46233 processed
#  Batch time: 92.21321439743042 s
#  Total time: 264.9672031402588 s
#
# 'entities'ss: [================================----------------------------] 54.0%% ...
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 4680, 'positive': 3390, 'neutral': 2819}, 'others': {'negative': 8256, 'positive': 15770, 'neutral': 18316}}
#
# 4000 of 46233 processed
#  Batch time: 98.89043498039246 s
#  Total time: 363.85780477523804 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 5133, 'positive': 3743, 'neutral': 3151}, 'others': {'negative': 9515, 'positive': 17634, 'neutral': 20413}}
#
# 5000 of 46233 processed
#  Batch time: 82.1348488330841 s
#  Total time: 445.992714881897 s
#
# 'entities'ss: [========----------------------------------------------------] 14.0%% ...
# 'entities'ss: [================--------------------------------------------] 26.0%% ...
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 5630, 'positive': 4092, 'neutral': 3414}, 'others': {'negative': 10811, 'positive': 19683, 'neutral': 22632}}
#
# 6000 of 46233 processed
#  Batch time: 112.07553243637085 s
#  Total time: 558.0683250427246 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 6153, 'positive': 4429, 'neutral': 3678}, 'others': {'negative': 12096, 'positive': 21512, 'neutral': 24762}}
#
# 7000 of 46233 processed
#  Batch time: 86.82160902023315 s
#  Total time: 644.8900065422058 s
#
# 'entities'ss: [==========================================------------------] 70.0%% ...
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 6695, 'positive': 4800, 'neutral': 3936}, 'others': {'negative': 13301, 'positive': 23206, 'neutral': 26763}}
#
# 8000 of 46233 processed
#  Batch time: 98.25205326080322 s
#  Total time: 743.1422011852264 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 7260, 'positive': 5137, 'neutral': 4288}, 'others': {'negative': 14365, 'positive': 24895, 'neutral': 28652}}
#
# 9000 of 46233 processed
#  Batch time: 91.42208456993103 s
#  Total time: 834.5646984577179 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 7740, 'positive': 5489, 'neutral': 4566}, 'others': {'negative': 15616, 'positive': 26909, 'neutral': 30882}}
#
# 10000 of 46233 processed
#  Batch time: 93.96700978279114 s
#  Total time: 928.5320591926575 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 8253, 'positive': 5876, 'neutral': 4852}, 'others': {'negative': 16778, 'positive': 28470, 'neutral': 32493}}
#
# 11000 of 46233 processed
#  Batch time: 89.01170921325684 s
#  Total time: 1017.5438442230225 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 8780, 'positive': 6279, 'neutral': 5102}, 'others': {'negative': 17778, 'positive': 30355, 'neutral': 34453}}
#
# 12000 of 46233 processed
#  Batch time: 84.36976981163025 s
#  Total time: 1101.9137246608734 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 9313, 'positive': 6668, 'neutral': 5398}, 'others': {'negative': 18736, 'positive': 31864, 'neutral': 36130}}
#
# 13000 of 46233 processed
#  Batch time: 94.93023228645325 s
#  Total time: 1196.8440289497375 s
#
# 'entities'ss: [================--------------------------------------------] 26.0%% ...
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 9839, 'positive': 7062, 'neutral': 5687}, 'others': {'negative': 19916, 'positive': 33715, 'neutral': 38387}}
#
# 14000 of 46233 processed
#  Batch time: 99.75739860534668 s
#  Total time: 1296.601483821869 s
#
# 'entities'ss: [==========--------------------------------------------------] 16.0%% ...
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 10466, 'positive': 7368, 'neutral': 6055}, 'others': {'negative': 21041, 'positive': 34961, 'neutral': 40073}}
#
# 15000 of 46233 processed
#  Batch time: 111.06102800369263 s
#  Total time: 1407.6626007556915 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 10961, 'positive': 7758, 'neutral': 6377}, 'others': {'negative': 22285, 'positive': 36593, 'neutral': 42167}}
#
# 16000 of 46233 processed
#  Batch time: 96.14320039749146 s
#  Total time: 1503.8058822154999 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 11514, 'positive': 8151, 'neutral': 6709}, 'others': {'negative': 23279, 'positive': 38165, 'neutral': 44369}}
#
# 17000 of 46233 processed
#  Batch time: 90.7793197631836 s
#  Total time: 1594.5852904319763 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 12129, 'positive': 8500, 'neutral': 7051}, 'others': {'negative': 24259, 'positive': 39655, 'neutral': 46421}}
#
# 18000 of 46233 processed
#  Batch time: 103.77238035202026 s
#  Total time: 1698.3577861785889 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 12659, 'positive': 8847, 'neutral': 7372}, 'others': {'negative': 25292, 'positive': 41334, 'neutral': 48541}}
#
# 19000 of 46233 processed
#  Batch time: 91.19697451591492 s
#  Total time: 1789.5548813343048 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 13200, 'positive': 9195, 'neutral': 7651}, 'others': {'negative': 26400, 'positive': 42840, 'neutral': 50616}}
#
# 20000 of 46233 processed
#  Batch time: 86.79524755477905 s
#  Total time: 1876.350224018097 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 13753, 'positive': 9523, 'neutral': 7924}, 'others': {'negative': 27811, 'positive': 44464, 'neutral': 52641}}
#
# 21000 of 46233 processed
#  Batch time: 87.56253409385681 s
#  Total time: 1963.9128246307373 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 14282, 'positive': 9874, 'neutral': 8214}, 'others': {'negative': 29102, 'positive': 46191, 'neutral': 54806}}
#
# 22000 of 46233 processed
#  Batch time: 86.97077178955078 s
#  Total time: 2050.8836963176727 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 14833, 'positive': 10195, 'neutral': 8499}, 'others': {'negative': 30269, 'positive': 48046, 'neutral': 57310}}
#
# 23000 of 46233 processed
#  Batch time: 88.99554896354675 s
#  Total time: 2139.8793869018555 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 15363, 'positive': 10540, 'neutral': 8776}, 'others': {'negative': 31512, 'positive': 49730, 'neutral': 59572}}
#
# 24000 of 46233 processed
#  Batch time: 88.54270839691162 s
#  Total time: 2228.422604084015 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 15926, 'positive': 10877, 'neutral': 9207}, 'others': {'negative': 32562, 'positive': 50979, 'neutral': 61070}}
#
# 25000 of 46233 processed
#  Batch time: 81.28755307197571 s
#  Total time: 2309.710215330124 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 16389, 'positive': 11196, 'neutral': 9516}, 'others': {'negative': 33506, 'positive': 52800, 'neutral': 63476}}
#
# 26000 of 46233 processed
#  Batch time: 89.62217330932617 s
#  Total time: 2399.3324835300446 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 16924, 'positive': 11547, 'neutral': 9844}, 'others': {'negative': 34456, 'positive': 54627, 'neutral': 65832}}
#
# 27000 of 46233 processed
#  Batch time: 86.21603012084961 s
#  Total time: 2485.548615217209 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 17480, 'positive': 11951, 'neutral': 10176}, 'others': {'negative': 35334, 'positive': 56165, 'neutral': 67884}}
#
# 28000 of 46233 processed
#  Batch time: 86.75521612167358 s
#  Total time: 2572.3039202690125 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 18081, 'positive': 12267, 'neutral': 10486}, 'others': {'negative': 36333, 'positive': 57892, 'neutral': 70028}}
#
# 29000 of 46233 processed
#  Batch time: 92.9743971824646 s
#  Total time: 2665.2783708572388 s
#
# 'entities'ss: [=======-----------------------------------------------------] 12.0%% ...
# 'entities'ss: [================--------------------------------------------] 26.0%% ...
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 18665, 'positive': 12625, 'neutral': 10775}, 'others': {'negative': 37535, 'positive': 59413, 'neutral': 71929}}
#
# 30000 of 46233 processed
#  Batch time: 106.28944039344788 s
#  Total time: 2771.567897081375 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 19171, 'positive': 12967, 'neutral': 11063}, 'others': {'negative': 38665, 'positive': 61298, 'neutral': 74218}}
#
# 31000 of 46233 processed
#  Batch time: 87.51175165176392 s
#  Total time: 2859.0797204971313 s
#
# 'entities'ss: [==================------------------------------------------] 30.0%% ...
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 19730, 'positive': 13298, 'neutral': 11335}, 'others': {'negative': 39993, 'positive': 62851, 'neutral': 76187}}
#
# 32000 of 46233 processed
#  Batch time: 98.98531317710876 s
#  Total time: 2958.0650913715363 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 20225, 'positive': 13686, 'neutral': 11682}, 'others': {'negative': 41133, 'positive': 64674, 'neutral': 78254}}
#
# 33000 of 46233 processed
#  Batch time: 97.45386481285095 s
#  Total time: 3055.519017934799 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 20702, 'positive': 14053, 'neutral': 11978}, 'others': {'negative': 42254, 'positive': 66574, 'neutral': 80359}}
#
# 34000 of 46233 processed
#  Batch time: 85.08528208732605 s
#  Total time: 3140.6044416427612 s
#
# 'entities'ss: [==================================--------------------------] 56.0%% ...
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 21227, 'positive': 14374, 'neutral': 12340}, 'others': {'negative': 43450, 'positive': 68191, 'neutral': 82240}}
#
# 35000 of 46233 processed
#  Batch time: 97.28744435310364 s
#  Total time: 3237.8919467926025 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 21697, 'positive': 14784, 'neutral': 12644}, 'others': {'negative': 44589, 'positive': 69886, 'neutral': 84294}}
#
# 36000 of 46233 processed
#  Batch time: 92.65629982948303 s
#  Total time: 3330.5483672618866 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 22186, 'positive': 15181, 'neutral': 12913}, 'others': {'negative': 45693, 'positive': 71690, 'neutral': 86770}}
#
# 37000 of 46233 processed
#  Batch time: 100.07061076164246 s
#  Total time: 3430.619034051895 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 22691, 'positive': 15547, 'neutral': 13238}, 'others': {'negative': 46624, 'positive': 73386, 'neutral': 89003}}
#
# 38000 of 46233 processed
#  Batch time: 95.94096994400024 s
#  Total time: 3526.5600719451904 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 23203, 'positive': 15955, 'neutral': 13548}, 'others': {'negative': 47769, 'positive': 75091, 'neutral': 91121}}
#
# 39000 of 46233 processed
#  Batch time: 92.62739038467407 s
#  Total time: 3619.1876480579376 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 23705, 'positive': 16315, 'neutral': 13839}, 'others': {'negative': 48792, 'positive': 76799, 'neutral': 93316}}
#
# 40000 of 46233 processed
#  Batch time: 93.40996742248535 s
#  Total time: 3712.597682952881 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 24229, 'positive': 16696, 'neutral': 14156}, 'others': {'negative': 49707, 'positive': 78586, 'neutral': 95620}}
#
# 41000 of 46233 processed
#  Batch time: 94.77530860900879 s
#  Total time: 3807.3730721473694 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 24763, 'positive': 17059, 'neutral': 14455}, 'others': {'negative': 50767, 'positive': 80197, 'neutral': 97553}}
#
# 42000 of 46233 processed
#  Batch time: 85.54232835769653 s
#  Total time: 3892.9156317710876 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 25325, 'positive': 17374, 'neutral': 14786}, 'others': {'negative': 51618, 'positive': 81571, 'neutral': 99368}}
#
# 43000 of 46233 processed
#  Batch time: 81.64298295974731 s
#  Total time: 3974.5586833953857 s
#
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 25888, 'positive': 17727, 'neutral': 15098}, 'others': {'negative': 52638, 'positive': 83078, 'neutral': 101484}}
#
# 44000 of 46233 processed
#  Batch time: 87.5326669216156 s
#  Total time: 4062.0914294719696 s
#
# 'entities'ss: [======------------------------------------------------------] 10.0%% ...
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 26550, 'positive': 18077, 'neutral': 15400}, 'others': {'negative': 53656, 'positive': 84386, 'neutral': 103219}}
#
# 45000 of 46233 processed
#  Batch time: 98.07931447029114 s
#  Total time: 4160.170969486237 s
#
# 'entities'ss: [======================--------------------------------------] 36.0%% ...
# IBM Progress: [============================================================] 100.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 27135, 'positive': 18396, 'neutral': 15716}, 'others': {'negative': 54652, 'positive': 85951, 'neutral': 105420}}
#
# 46000 of 46233 processed
#  Batch time: 97.81449246406555 s
#  Total time: 4257.986129283905 s
# IBM Progress: [==============================================================] 103.0%% ...
#
# {'le_5_orgs_conf_gt_06': {'negative': 27268, 'positive': 18504, 'neutral': 15797}, 'others': {'negative': 54923, 'positive': 86365, 'neutral': 105878}}
#
# 47000 of 46233 processed
#  Batch time: 22.340089082717896 s
#  Total time: 4280.326284170151 s

# %%
orgs = pd.read_csv('orgs_ibm_checked.csv')

# %%
orgs.describe()
# Out:
#        sentiment_score  org_relevance      org_count     confidence  \
# count    308736.000000  308735.000000  308736.000000  308735.000000
# mean          0.063065       0.318774       1.903801       0.832420
# std           0.544280       0.259042       2.439571       0.215769
# min          -0.999882       0.000000       1.000000       0.005197
# 25%          -0.333363       0.119981       1.000000       0.718066
# 50%           0.000000       0.248588       1.000000       0.942977
# 75%           0.577635       0.448576       2.000000       0.996309
# max           0.999930       0.999900      52.000000       1.000000
#
#          orgs_in_doc
# count  308736.000000
# mean       10.376879
# std         6.666681
# min         1.000000
# 25%         6.000000
# 50%         9.000000
# 75%        14.000000
# max        47.000000
